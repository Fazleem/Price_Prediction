# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
train_size = 0.7
dev_size = 0.1
test_size = 0.2

# %%
df = pd.read_csv("../data/raw/BTC-USD.csv", parse_dates=['Date'])
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2015-09-27    234.139008    234.526001    232.475998    232.757004
# 1    2015-09-28    232.835999    239.339005    232.466995    239.141998
# 2    2015-09-29    239.016006    239.802002    235.927994    236.686996
# 3    2015-09-30    236.639999    237.733994    235.628998    236.059998
# 4    2015-10-01    236.003998    238.445007    235.615997    237.548996
# ...         ...           ...           ...           ...           ...
# 1820 2020-09-20  11095.870117  11095.870117  10814.477539  10938.271484
# 1821 2020-09-21  10934.925781  10988.304688  10380.260742  10462.259766
# 1822 2020-09-22  10459.624023  10568.077148  10382.726563  10538.459961
# 1823 2020-09-23  10539.457031  10637.847656  10185.774414  10225.864258
# 1824 2020-09-24  10227.479492  10765.794922  10215.205078  10745.548828
#
#          Adj Close        Volume
# 0       232.757004  1.417990e+07
# 1       239.141998  2.471300e+07
# 2       236.686996  2.269130e+07
# 3       236.059998  1.974350e+07
# 4       237.548996  2.048880e+07
# ...            ...           ...
# 1820  10938.271484  2.469952e+10
# 1821  10462.259766  2.888500e+10
# 1822  10538.459961  2.362179e+10
# 1823  10225.864258  2.298673e+10
# 1824  10745.548828  2.301754e+10
#
# [1825 rows x 7 columns]

# %%
# df = df.sample(frac=1, random_state=42)
#scale the data
scaler = MinMaxScaler(feature_range=(0,1))
df = scaler.fit_transform(np.array(df).reshape(-1,1))
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-a1a1b1f25df4> in <module>
#       2 #scale the data
#       3 scaler = MinMaxScaler(feature_range=(0,1))
# ----> 4 df = scaler.fit_transform(np.array(df).reshape(-1,1))
#       5 df
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y)
#     334         # Reset internal state before fitting
#     335         self._reset()
# --> 336         return self.partial_fit(X, y)
#     337
#     338     def partial_fit(self, X, y=None):
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in partial_fit(self, X, y)
#     367
#     368         first_pass = not hasattr(self, 'n_samples_seen_')
# --> 369         X = self._validate_data(X, reset=first_pass,
#     370                                 estimator=self, dtype=FLOAT_DTYPES,
#     371                                 force_all_finite="allow-nan")
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# ~/Desktop/DataScience/bitcoin_price_prediction/venv/lib/python3.8/site-packages/numpy/core/_asarray.py in asarray(a, dtype, order)
#      81
#      82     """
# ---> 83     return array(a, dtype, copy=False, order=order)
#      84
#      85
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
data_array = df.values
data_shape = data_array.shape
# data_shape

# %%
train_length = round(data_array.shape[0] * train_size)
dev_length = round(data_array.shape[0] * dev_size)
test_length = round(data_array.shape[0] * test_size)

#get the data into arrays
train_array = data_array[:train_length]
dev_array = data_array[train_length:(train_length + dev_length)]
test_array = data_array[(train_length+dev_length):]

# %%
np.save("../data/interim/train_data.npy", train_array)
np.save("../data/interim/dev_data.npy", dev_array)
np.save("../data/interim/test_data.npy", test_array)

#test if data is loaded correctly
# sample_test = np.load("../data/interim/dev_data.npy", allow_pickle=True)
#sample_test.shape
